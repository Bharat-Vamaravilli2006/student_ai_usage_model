# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/home/user/dsp/dirty_student_ai_dataset.csv")

# %%
df.info()
df.shape
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10200 entries, 0 to 10199
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   StudentLevel              9753 non-null   object
#  1   Discipline                9344 non-null   object
#  2   SessionDate               9720 non-null   object
#  3   SessionLengthMin          9206 non-null   float64
#  4   TotalPrompts              9696 non-null   float64
#  5   TaskType                  9731 non-null   object
#  6   AI_AssistanceLevel        9715 non-null   float64
#  7   FinalOutcome              9762 non-null   object
#  8   UsedAgain                 9762 non-null   object
#  9   SatisfactionRating        9159 non-null   float64
#  10  DayOfWeek                 9794 non-null   object
#  11  IsWeekend                 9752 non-null   object
#  12  PromptsPerMinute          9202 non-null   float64
#  13  EstimatedSessionCost_USD  9697 non-null   float64
#  14  StudentAge                9701 non-null   float64
#  15  AcademicPressureScore     9663 non-null   float64
#  16  GpaImprovement            9683 non-null   float64
# dtypes: float64(9), object(8)
# memory usage: 1.3+ MB
#        SessionLengthMin  TotalPrompts  AI_AssistanceLevel  SatisfactionRating  \
# count       9206.000000   9696.000000         9715.000000         9159.000000
# mean          21.953496      6.752893            3.473803            3.412687
# std           47.340663     25.606754            0.990696            1.143270
# min            0.030000      1.000000            1.000000            1.000000
# 25%            9.610000      2.000000            3.000000            2.600000
# 50%           16.700000      4.000000            4.000000            3.500000
# 75%           26.700000      8.000000            4.000000            4.400000
# max          991.920315    560.602310            5.000000            5.000000
#
#        PromptsPerMinute  EstimatedSessionCost_USD   StudentAge  \
# count       9202.000000               9697.000000  9701.000000
# mean           0.287944                  0.055845    21.095351
# std            0.374287                  0.046233     4.467902
# min            0.100000                  0.010000    14.000000
# 25%            0.210000                  0.020000    18.000000
# 50%            0.260000                  0.040000    20.000000
# 75%            0.340000                  0.080000    23.000000
# max           33.330000                  0.390000    34.000000
#
#        AcademicPressureScore  GpaImprovement
# count            9663.000000     9683.000000
# mean               50.678878        0.248729
# std                28.733810        0.143334
# min                 1.000000        0.000000
# 25%                26.000000        0.130000
# 50%                51.000000        0.250000
# 75%                76.000000        0.370000
# max               100.000000        0.500000

# %%
df["StudentLevel"] = df["StudentLevel"].str.strip()
df["Discipline"] = df["Discipline"].str.strip()
df["SessionDate"] = df["SessionDate"].str.strip()
df["TaskType"] = df["TaskType"].str.strip()
df["FinalOutcome"] = df["FinalOutcome"].str.strip()
df["UsedAgain"] = df["UsedAgain"].str.strip()
df["DayOfWeek"] = df["DayOfWeek"].str.strip()
df["IsWeekend"] = df["IsWeekend"].str.strip()
df.IsWeekend.value_counts()
# Out:
# IsWeekend
# False    5585
# True     2282
# false     685
# FALSE     617
# true      274
# TRUE      234
# NAN        47
# nan        28
# Name: count, dtype: int64

# %%
missing= [""," ","NA","N/A","na","n/a","NAN","nan",None]
df.isin(missing).sum()
# Out:
# StudentLevel                 68
# Discipline                  115
# SessionDate                  49
# SessionLengthMin              0
# TotalPrompts                  0
# TaskType                     73
# AI_AssistanceLevel            0
# FinalOutcome                 65
# UsedAgain                    81
# SatisfactionRating            0
# DayOfWeek                    59
# IsWeekend                    75
# PromptsPerMinute              0
# EstimatedSessionCost_USD      0
# StudentAge                    0
# AcademicPressureScore         0
# GpaImprovement                0
# dtype: int64

# %%
df = df.replace(missing,np.nan)
df.isin(missing).sum()
# Out:
# StudentLevel                0
# Discipline                  0
# SessionDate                 0
# SessionLengthMin            0
# TotalPrompts                0
# TaskType                    0
# AI_AssistanceLevel          0
# FinalOutcome                0
# UsedAgain                   0
# SatisfactionRating          0
# DayOfWeek                   0
# IsWeekend                   0
# PromptsPerMinute            0
# EstimatedSessionCost_USD    0
# StudentAge                  0
# AcademicPressureScore       0
# GpaImprovement              0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# StudentLevel                 515
# Discipline                   971
# SessionDate                  529
# SessionLengthMin             994
# TotalPrompts                 504
# TaskType                     542
# AI_AssistanceLevel           485
# FinalOutcome                 503
# UsedAgain                    519
# SatisfactionRating          1041
# DayOfWeek                    465
# IsWeekend                    523
# PromptsPerMinute             998
# EstimatedSessionCost_USD     503
# StudentAge                   499
# AcademicPressureScore        537
# GpaImprovement               517
# dtype: int64

# %%
pd.DataFrame({"Missing":df.isnull().sum(),"percentage":(df.isnull().sum()/len(df))*100,"datatypes":df.dtypes}).query("Missing>0")
# Out:
#                           Missing  percentage datatypes
# StudentLevel                  515    5.049020    object
# Discipline                    971    9.519608    object
# SessionDate                   529    5.186275    object
# SessionLengthMin              994    9.745098   float64
# TotalPrompts                  504    4.941176   float64
# TaskType                      542    5.313725    object
# AI_AssistanceLevel            485    4.754902   float64
# FinalOutcome                  503    4.931373    object
# UsedAgain                     519    5.088235    object
# SatisfactionRating           1041   10.205882   float64
# DayOfWeek                     465    4.558824    object
# IsWeekend                     523    5.127451    object
# PromptsPerMinute              998    9.784314   float64
# EstimatedSessionCost_USD      503    4.931373   float64
# StudentAge                    499    4.892157   float64
# AcademicPressureScore         537    5.264706   float64
# GpaImprovement                517    5.068627   float64

# %%
df.StudentLevel.value_counts()
df["StudentLevel"] = df["StudentLevel"].fillna(df["StudentLevel"].mode()[0])
df.StudentLevel.isnull().sum()
# Out:
# np.int64(0)

# %%
df.Discipline.describe()
df["Discipline"] = df["Discipline"].fillna("Unknown")
df.Discipline.isnull().sum()
# Out:
# np.int64(0)

# %%
df.SessionDate.describe()
df["SessionDate"] = pd.to_datetime(df["SessionDate"],errors = "coerce")
df["SessionDate"] = df.SessionDate.fillna(method="ffill")
df.SessionDate.isnull().sum()
# Out:
# /tmp/ipykernel_5943/2461652687.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["SessionDate"] = df.SessionDate.fillna(method="ffill")
# np.int64(0)

# %%
df.SessionLengthMin.describe()
df.SessionLengthMin.isnull().all()
df.SessionLengthMin.median()
df["SessionLengthMin"]= df["SessionLengthMin"].fillna(df["SessionLengthMin"].median())
df.SessionLengthMin.isnull().sum()
# Out:
# np.int64(0)

# %%
df.TotalPrompts.describe()
df["TotalPrompts"] = df.TotalPrompts.fillna(df.TotalPrompts.median())
df.TotalPrompts.isnull().sum()
# Out:
# np.int64(0)

# %%
df = df.fillna({"TaskType":df["TaskType"].mode().iloc[0],
                "FinalOutcome":df["FinalOutcome"].mode().iloc[0],
                "UsedAgain":df["UsedAgain"].mode().iloc[0],
                "SatisfactionRating":df["SatisfactionRating"].median(),
                "AI_AssistanceLevel":df["AI_AssistanceLevel"].median(),
                "DayOfWeek":df["DayOfWeek"].mode().iloc[0],
                "IsWeekend":"Unknown"
                })

# %%
df = df.fillna({
    "PromptsPerMinute":df["PromptsPerMinute"].mode().iloc[0],
    "EstimatedSessionCost_USD":df["EstimatedSessionCost_USD"].mode().iloc[0],
    "StudentAge":df["StudentAge"].mode().iloc[0],
    "AcademicPressureScore":df["AcademicPressureScore"].median(),
    "GpaImprovement":df["GpaImprovement"].median()
})

# %%
df.isnull().sum()[df.isnull().any()]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(6)

# %%
df = df.drop_duplicates()

# %% [markdown]
# Data Formatting

# %%
df.dtypes
# Out:
# StudentLevel                        object
# Discipline                          object
# SessionDate                 datetime64[ns]
# SessionLengthMin                   float64
# TotalPrompts                       float64
# TaskType                            object
# AI_AssistanceLevel                 float64
# FinalOutcome                        object
# UsedAgain                           object
# SatisfactionRating                 float64
# DayOfWeek                           object
# IsWeekend                           object
# PromptsPerMinute                   float64
# EstimatedSessionCost_USD           float64
# StudentAge                         float64
# AcademicPressureScore              float64
# GpaImprovement                     float64
# dtype: object

# %%
df.head()
# Out:
#     StudentLevel        Discipline SessionDate  SessionLengthMin  \
# 0  Undergraduate  Computer Science  2024-11-03             31.20
# 1  Undergraduate        psychology  2024-11-03             13.09
# 2  Undergraduate          Business  2024-11-03             19.22
# 3  Undergraduate           Unknown  2025-05-06              3.70
# 4  Undergraduate        Psychology  2025-03-18             28.12
#
#    TotalPrompts  TaskType  AI_AssistanceLevel          FinalOutcome UsedAgain  \
# 0          11.0  STUDYING                 2.0  ASSIGNMENT COMPLETED      true
# 1           6.0  Studying                 3.0  Assignment Completed      True
# 2           5.0    Coding                 3.0  Assignment Completed      True
# 3           4.0    Coding                 3.0  Assignment Completed      True
# 4           9.0   Writing                 3.0  Assignment Completed      True
#
#    SatisfactionRating DayOfWeek IsWeekend  PromptsPerMinute  \
# 0                 1.0    sunday      True              0.35
# 1                 2.0    Sunday      True              0.46
# 2                 3.3    Sunday      True              0.26
# 3                 3.5   Tuesday     False              0.20
# 4                 2.9   TUESDAY     False              0.32
#
#    EstimatedSessionCost_USD  StudentAge  AcademicPressureScore  GpaImprovement
# 0                      0.11        23.0                   87.0            0.22
# 1                      0.06        21.0                   27.0            0.06
# 2                      0.05        20.0                   95.0            0.39
# 3                      0.01        22.0                   85.0            0.47
# 4                      0.09        23.0                   56.0            0.16

# %%
df.StudentLevel.value_counts()
df["StudentLevel"] = df["StudentLevel"].str.lower()
df["StudentLevel"] =df["StudentLevel"].str.title()
df.StudentLevel.value_counts()
# Out:
# StudentLevel
# Undergraduate    6333
# High School      1935
# Graduate         1926
# Name: count, dtype: int64

# %%
df.Discipline.value_counts()
df["Discipline"] = df["Discipline"].str.lower()
df.Discipline.value_counts()
df["Discipline"] = df["Discipline"].str.title()
df.Discipline.value_counts()
# Out:
# Discipline
# Biology             1355
# Engineering         1320
# Computer Science    1313
# Math                1313
# History             1313
# Psychology          1308
# Business            1302
# Unknown              970
# Name: count, dtype: int64

# %%
df.AI_AssistanceLevel.value_counts()
df.AI_AssistanceLevel = df.AI_AssistanceLevel.astype(int)
df.AI_AssistanceLevel.value_counts()
# Out:
# AI_AssistanceLevel
# 4    3834
# 3    3276
# 5    1524
# 2    1326
# 1     234
# Name: count, dtype: int64

# %%
df.FinalOutcome.value_counts()
df.FinalOutcome = df.FinalOutcome.str.title()
df.FinalOutcome.value_counts()
# Out:
# FinalOutcome
# Assignment Completed    5122
# Idea Drafted            2758
# Confused                1582
# Gave Up                  732
# Name: count, dtype: int64

# %%
df.UsedAgain.value_counts()
df.UsedAgain = df.UsedAgain.str.title()
df.UsedAgain.value_counts()
# Out:
# UsedAgain
# True     7337
# False    2857
# Name: count, dtype: int64

# %%
df.DayOfWeek.value_counts()
df.DayOfWeek = df.DayOfWeek.str.title()
df.DayOfWeek.value_counts()
# Out:
# DayOfWeek
# Friday       1908
# Sunday       1409
# Saturday     1391
# Thursday     1391
# Monday       1382
# Wednesday    1366
# Tuesday      1347
# Name: count, dtype: int64

# %%
df.IsWeekend.value_counts()
df.IsWeekend = df.IsWeekend.str.title()
df.IsWeekend.value_counts()
# Out:
# IsWeekend
# False      6884
# True       2787
# Unknown     523
# Name: count, dtype: int64

# %%
df.TaskType.value_counts()
df["TaskType"] = df["TaskType"].str.title()
df.TaskType.value_counts()
# Out:
# TaskType
# Writing          3531
# Studying         1973
# Coding           1901
# Homework Help    1881
# Research          456
# Brainstorming     452
# Name: count, dtype: int64

# %%
df.StudentAge.value_counts()
df.StudentAge = df.StudentAge.astype(int)
df.StudentAge.value_counts()
# Out:
# StudentAge
# 18    1913
# 22    1092
# 23    1088
# 20    1005
# 19     976
# 21     955
# 17     405
# 15     386
# 16     369
# 14     367
# 32     168
# 28     163
# 33     157
# 31     154
# 26     154
# 24     153
# 30     146
# 27     143
# 34     141
# 29     135
# 25     124
# Name: count, dtype: int64

# %%
df.AcademicPressureScore.value_counts()
df.AcademicPressureScore =df.AcademicPressureScore.astype(int)
df.AcademicPressureScore.value_counts()
# Out:
# AcademicPressureScore
# 51    642
# 14    129
# 60    125
# 34    120
# 37    119
#      ...
# 69     80
# 53     79
# 92     78
# 12     75
# 24     71
# Name: count, Length: 100, dtype: int64

# %%
df.TotalPrompts.value_counts()
df.TotalPrompts = df.TotalPrompts.astype(int)
df.TotalPrompts.value_counts()
# Out:
# TotalPrompts
# 4      1574
# 1      1544
# 2      1234
# 3      1184
# 5       804
# 6       786
# 7       585
# 8       463
# 9       405
# 10      324
# 11      258
# 12      205
# 13      159
# 14      122
# 15      111
# 16       92
# 17       69
# 18       50
# 19       40
# 20       34
# 22       25
# 21       25
# 560      20
# 23       18
# 25       12
# 26       10
# 24       10
# 28        8
# 31        4
# 29        4
# 38        3
# 27        3
# 39        2
# 34        2
# 30        2
# 32        1
# 33        1
# 36        1
# Name: count, dtype: int64

# %%
df = df.rename(columns={"Discipline":"Department"})

# %%
df.head(3)
# Out:
#     StudentLevel        Department SessionDate  SessionLengthMin  \
# 0  Undergraduate  Computer Science  2024-11-03             31.20
# 1  Undergraduate        Psychology  2024-11-03             13.09
# 2  Undergraduate          Business  2024-11-03             19.22
#
#    TotalPrompts  TaskType  AI_AssistanceLevel          FinalOutcome UsedAgain  \
# 0            11  Studying                   2  Assignment Completed      True
# 1             6  Studying                   3  Assignment Completed      True
# 2             5    Coding                   3  Assignment Completed      True
#
#    SatisfactionRating DayOfWeek IsWeekend  PromptsPerMinute  \
# 0                 1.0    Sunday      True              0.35
# 1                 2.0    Sunday      True              0.46
# 2                 3.3    Sunday      True              0.26
#
#    EstimatedSessionCost_USD  StudentAge  AcademicPressureScore  GpaImprovement
# 0                      0.11          23                     87            0.22
# 1                      0.06          21                     27            0.06
# 2                      0.05          20                     95            0.39

# %%
df.SatisfactionRating.value_counts()
df.SatisfactionRating.nunique()
df["SatisfactionRating"] = pd.cut(df["SatisfactionRating"],bins=[0,1.5,2.5,3.5,4.5,5],labels = [1,2,3,4,5])
df["SatisfactionRating"].value_counts()
# Out:
# SatisfactionRating
# 3    3579
# 4    2534
# 5    1878
# 2    1521
# 1     682
# Name: count, dtype: int64

# %%
(df["SessionLengthMin"]>100).sum()
df = df[df["SessionLengthMin"]<100]
(df["SessionLengthMin"]>100).sum()
# Out:
# np.int64(0)

# %%
df = df[df["TotalPrompts"]<100]
(df["TotalPrompts"]>100).sum()
# Out:
# np.int64(0)

# %%
df.IsWeekend.value_counts()
# Out:
# IsWeekend
# False      6857
# True       2778
# Unknown     518
# Name: count, dtype: int64

# %%
df.SatisfactionRating = df.SatisfactionRating.astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10153 entries, 0 to 10199
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   StudentLevel              10153 non-null  object
#  1   Department                10153 non-null  object
#  2   SessionDate               10153 non-null  datetime64[ns]
#  3   SessionLengthMin          10153 non-null  float64
#  4   TotalPrompts              10153 non-null  int64
#  5   TaskType                  10153 non-null  object
#  6   AI_AssistanceLevel        10153 non-null  int64
#  7   FinalOutcome              10153 non-null  object
#  8   UsedAgain                 10153 non-null  object
#  9   SatisfactionRating        10153 non-null  int64
#  10  DayOfWeek                 10153 non-null  object
#  11  IsWeekend                 10153 non-null  object
#  12  PromptsPerMinute          10153 non-null  float64
#  13  EstimatedSessionCost_USD  10153 non-null  float64
#  14  StudentAge                10153 non-null  int64
#  15  AcademicPressureScore     10153 non-null  int64
#  16  GpaImprovement            10153 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(5), object(7)
# memory usage: 1.4+ MB

# %%
df["IsWeekend"] = df.apply(lambda x: True if (x["DayOfWeek"]=="Saturday") or (x["DayOfWeek"]=="Sunday") else False, axis=1)
df["IsWeekend"].value_counts()
# Out:
# IsWeekend
# False    7363
# True     2790
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10153 entries, 0 to 10199
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   StudentLevel              10153 non-null  object
#  1   Department                10153 non-null  object
#  2   SessionDate               10153 non-null  datetime64[ns]
#  3   SessionLengthMin          10153 non-null  float64
#  4   TotalPrompts              10153 non-null  int64
#  5   TaskType                  10153 non-null  object
#  6   AI_AssistanceLevel        10153 non-null  int64
#  7   FinalOutcome              10153 non-null  object
#  8   UsedAgain                 10153 non-null  object
#  9   SatisfactionRating        10153 non-null  int64
#  10  DayOfWeek                 10153 non-null  object
#  11  IsWeekend                 10153 non-null  bool
#  12  PromptsPerMinute          10153 non-null  float64
#  13  EstimatedSessionCost_USD  10153 non-null  float64
#  14  StudentAge                10153 non-null  int64
#  15  AcademicPressureScore     10153 non-null  int64
#  16  GpaImprovement            10153 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(5), object(6)
# memory usage: 1.3+ MB

# %%
df
# Out:
#         StudentLevel        Department SessionDate  SessionLengthMin  \
# 0      Undergraduate  Computer Science  2024-11-03             31.20
# 1      Undergraduate        Psychology  2024-11-03             13.09
# 2      Undergraduate          Business  2024-11-03             19.22
# 3      Undergraduate           Unknown  2025-05-06              3.70
# 4      Undergraduate        Psychology  2025-03-18             28.12
# ...              ...               ...         ...               ...
# 10195       Graduate           Biology  2025-06-01              4.43
# 10196  Undergraduate           Biology  2024-09-17             20.38
# 10197  Undergraduate           History  2025-01-29             15.68
# 10198  Undergraduate           Unknown  2025-03-08             10.38
# 10199  Undergraduate          Business  2025-06-05             16.70
#
#        TotalPrompts       TaskType  AI_AssistanceLevel          FinalOutcome  \
# 0                11       Studying                   2  Assignment Completed
# 1                 6       Studying                   3  Assignment Completed
# 2                 5         Coding                   3  Assignment Completed
# 3                 4         Coding                   3  Assignment Completed
# 4                 9        Writing                   3  Assignment Completed
# ...             ...            ...                 ...                   ...
# 10195             1         Coding                   4  Assignment Completed
# 10196             7  Homework Help                   3          Idea Drafted
# 10197             3        Writing                   5  Assignment Completed
# 10198             3        Writing                   2  Assignment Completed
# 10199             7  Homework Help                   5              Confused
#
#       UsedAgain  SatisfactionRating  DayOfWeek  IsWeekend  PromptsPerMinute  \
# 0          True                   1     Sunday       True              0.35
# 1          True                   2     Sunday       True              0.46
# 2          True                   3     Sunday       True              0.26
# 3          True                   3    Tuesday      False              0.20
# 4          True                   3    Tuesday      False              0.32
# ...         ...                 ...        ...        ...               ...
# 10195      True                   5     Sunday       True              0.23
# 10196      True                   2    Tuesday      False              0.34
# 10197      True                   5  Wednesday      False              0.19
# 10198     False                   2   Saturday       True              0.29
# 10199     False                   4   Thursday      False              0.20
#
#        EstimatedSessionCost_USD  StudentAge  AcademicPressureScore  \
# 0                          0.11          23                     87
# 1                          0.06          21                     27
# 2                          0.05          20                     95
# 3                          0.01          22                     85
# 4                          0.09          23                     56
# ...                         ...         ...                    ...
# 10195                      0.01          32                     81
# 10196                      0.01          21                     51
# 10197                      0.03          23                     35
# 10198                      0.03          23                     60
# 10199                      0.07          18                     80
#
#        GpaImprovement
# 0                0.22
# 1                0.06
# 2                0.39
# 3                0.47
# 4                0.16
# ...               ...
# 10195            0.10
# 10196            0.25
# 10197            0.05
# 10198            0.08
# 10199            0.17
#
# [10153 rows x 17 columns]

# %% [markdown]
# creating a new cleaned dataset

# %%
df.to_csv("/home/user/dsp/cleaned_student_ai_dataset.csv",index=False)

# %% [markdown]
# VISUALIZATION

# %%
import matplotlib.pyplot as plt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10153 entries, 0 to 10199
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   StudentLevel              10153 non-null  object
#  1   Department                10153 non-null  object
#  2   SessionDate               10153 non-null  datetime64[ns]
#  3   SessionLengthMin          10153 non-null  float64
#  4   TotalPrompts              10153 non-null  int64
#  5   TaskType                  10153 non-null  object
#  6   AI_AssistanceLevel        10153 non-null  int64
#  7   FinalOutcome              10153 non-null  object
#  8   UsedAgain                 10153 non-null  object
#  9   SatisfactionRating        10153 non-null  int64
#  10  DayOfWeek                 10153 non-null  object
#  11  IsWeekend                 10153 non-null  bool
#  12  PromptsPerMinute          10153 non-null  float64
#  13  EstimatedSessionCost_USD  10153 non-null  float64
#  14  StudentAge                10153 non-null  int64
#  15  AcademicPressureScore     10153 non-null  int64
#  16  GpaImprovement            10153 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(5), object(6)
# memory usage: 1.3+ MB

# %%
df.head()
# Out:
#     StudentLevel        Department SessionDate  SessionLengthMin  \
# 0  Undergraduate  Computer Science  2024-11-03             31.20
# 1  Undergraduate        Psychology  2024-11-03             13.09
# 2  Undergraduate          Business  2024-11-03             19.22
# 3  Undergraduate           Unknown  2025-05-06              3.70
# 4  Undergraduate        Psychology  2025-03-18             28.12
#
#    TotalPrompts  TaskType  AI_AssistanceLevel          FinalOutcome UsedAgain  \
# 0            11  Studying                   2  Assignment Completed      True
# 1             6  Studying                   3  Assignment Completed      True
# 2             5    Coding                   3  Assignment Completed      True
# 3             4    Coding                   3  Assignment Completed      True
# 4             9   Writing                   3  Assignment Completed      True
#
#    SatisfactionRating DayOfWeek  IsWeekend  PromptsPerMinute  \
# 0                   1    Sunday       True              0.35
# 1                   2    Sunday       True              0.46
# 2                   3    Sunday       True              0.26
# 3                   3   Tuesday      False              0.20
# 4                   3   Tuesday      False              0.32
#
#    EstimatedSessionCost_USD  StudentAge  AcademicPressureScore  GpaImprovement
# 0                      0.11          23                     87            0.22
# 1                      0.06          21                     27            0.06
# 2                      0.05          20                     95            0.39
# 3                      0.01          22                     85            0.47
# 4                      0.09          23                     56            0.16

# %%
plt.boxplot(df["SessionLengthMin"])
plt.show()
print(df["SessionLengthMin"].dtype)
print(df["SessionLengthMin"].count())
print(df["SessionLengthMin"].nunique())
# Out:
# float64
# 10153
# 3912

# %%
df.SatisfactionRating.value_counts().plot(kind="bar")

plt.legend(loc="upper right")
plt.show()

# %%
df.SessionLengthMin.plot(kind="hist",color= "teal", bins=20)
plt.xlabel("Sessionlength in minutes")
plt.ylabel("Frequency")
plt.title("Distribution of Session Lengths")
plt.legend(loc="upper right")
plt.show()

# %%
df["StudentLevel"].value_counts().plot(kind="bar")
plt.show()
